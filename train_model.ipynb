# %%
from base_miner.model import create_and_save_base_model_lstm
from base_miner.get_data import prep_data, scale_data

# %%
data = prep_data()
scaler, X, y = scale_data(data)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
mse = create_and_save_base_model_lstm(scaler, X, y, "bitmind_base_lstm")
# Out:
# Epoch 1/100
# /Users/kenmiyachi/anaconda3/envs/snp/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - loss: 0.1886
# Epoch 2/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step - loss: 0.0074
# Epoch 3/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - loss: 0.0061
# Epoch 4/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - loss: 0.0052
# Epoch 5/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step - loss: 0.0049
# Epoch 6/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step - loss: 0.0040
# Epoch 7/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step - loss: 0.0037
# Epoch 8/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step - loss: 0.0035
# Epoch 9/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step - loss: 0.0032
# Epoch 10/100
# ...
